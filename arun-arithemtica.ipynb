# %%
# Python Operators

a = 20
b = 7

# Arithmetic77 operators
print(20 + 7)   # Addition
print(20 - 7)   # Subtraction
print(20 * 7)   # Multiplication
print(20 / 7)   # Division
print(20 // 7)  # Floor division
print(20 % 7)   # Modulus
print(20 ** 7)  # Exponentiation
# Out:
# 27
# 13
# 140
# 2.857142857142857
# 2
# 6
# 1280000000

# %%
#Assignment operators
# =,+=,-=,/=,*=,**=,//=,%=

a = 10
print(a)  # Output: 10
a += 5
print(a)  # a = a + 5, Output: 15
a += 2
print(a)  # a = a + 2   Output: 17

b = 0
b += 20
print(b)  # b = b + 20, Output: 20
# Out:
# 10
# 15
# 17
# 20
