# %%
x = 10
y = 5
print (x + y)
print (x * y)
# Out:
# 15
# 50

# %%
"name" = "arunjahaan"
"age" = 30
"course" = "Gen AI"
"profession" = "medical techie"

print("name:", name)
print("age:", age)
print("course:", course)
print("profession:", profession)

# %%
num1 = 27
num2 = 27

print(num1 + num2)
print(num1 * num2)
print(num1 - num2)
print(num1 / num2)
print(num1 % num2)
print(num1 // num2)
# Out:
# 54
# 729
# 0
# 1.0
# 0
# 1

# %%
name = "arun kumar"
print ("hello", name)
# Out:
# hello arun kumar

# %%
a = "10"
b = int(a)
print(b+5)
# Out:
# 15

# %%
numbers = [10,20,30,40,50]
print(numbers[1])
# Out:
# 20

# %%
student = {"name":"arun","age":30,"sex":"male","address":"east tambaram","city":"chennai","birth_state":"pondycherry","state":"tamilnadu","dream state":"kerala & karnataka","country":"india"}
print(student["age"])
print(student["sex"])
print(student["address"])
print(student["city"])
print(student["birth_state"])
print(student["state"])
print(student["dream state"])
print(student["country"])
# Out:
# 30
# male
# east tambaram
# chennai
# pondycherry
# tamilnadu
# kerala & karnataka
# india
